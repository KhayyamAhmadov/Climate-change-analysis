# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Acer\Desktop\climate data\Total Wildland Fires and Acres (1983-2020).csv")

# %%
df
# Out:
#     Year   Fires       Acres
# 0   2020  58,950  10,122,336
# 1   2019  50,477   4,664,364
# 2   2018  58,083   8,767,492
# 3   2017  71,499  10,026,086
# 4   2016  67,743   5,509,995
# 5   2015  68,151  10,125,149
# 6   2014  63,312   3,595,613
# 7   2013  47,579   4,319,546
# 8   2012  67,774   9,326,238
# 9   2011  74,126   8,711,367
# 10  2010  71,971   3,422,724
# 11  2009  78,792   5,921,786
# 12  2008  78,979   5,292,468
# 13  2007  85,705   9,328,045
# 14  2006  96,385   9,873,745
# 15  2005  66,753   8,689,389
# 16  2004  65,461  *8,097,880
# 17  2003  63,629   3,960,842
# 18  2002  73,457   7,184,712
# 19  2001  84,079   3,570,911
# 20  2000  92,250   7,393,493
# 21  1999  92,487   5,626,093
# 22  1998  81,043   1,329,704
# 23  1997  66,196   2,856,959
# 24  1996  96,363   6,065,998
# 25  1995  82,234   1,840,546
# 26  1994  79,107   4,073,579
# 27  1993  58,810   1,797,574
# 28  1992  87,394   2,069,929
# 29  1991  75,754   2,953,578
# 30  1990  66,481   4,621,621
# ...

# %%
df.loc[16]
# Out:
# Year           2004
# Fires        65,461
# Acres    *8,097,880
# Name: 16, dtype: object

# %%
df = df.drop(16)

# %%
df['Fires'] = df['Fires'].str.replace(',', '').astype(int)
df['Acres'] = df['Acres'].str.replace(',', '').astype(float)

# %%
df.dtypes
# Out:
# Year       int64
# Fires      int64
# Acres    float64
# dtype: object

# %%
plt.figure(figsize=(10,8))
plt.plot(df['Year'],df['Fires'],'o-')

# %%
plt.figure(figsize=(10,8))
plt.plot(df['Year'], df['Acres'],'o-')

# %%
# subplot , 2 cedvel
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

#yanğın sayi qrafiki
ax1.plot(df['Year'], df["Fires"], color="red", marker="o")
ax1.set_title("İllər üzrə meşə yanğınlarının sayı")
ax1.set_ylabel("Yanğın sayı")
ax1.grid(True)

#yanmiş sahe qrafiki
ax2.plot(df['Year'], df["Acres"], color="orange", marker="o")
ax2.set_title("İllər üzrə yanmış sahə (akr - 1 akr ≈ 4046.86 kvadrat metr ) ", fontsize=12)
ax2.set_xlabel("İllər")
ax2.set_ylabel("Akr")
ax2.grid(True)

plt.show()

# %%
df
# Out:
#     Year  Fires       Acres
# 0   2020  58950  10122336.0
# 1   2019  50477   4664364.0
# 2   2018  58083   8767492.0
# 3   2017  71499  10026086.0
# 4   2016  67743   5509995.0
# 5   2015  68151  10125149.0
# 6   2014  63312   3595613.0
# 7   2013  47579   4319546.0
# 8   2012  67774   9326238.0
# 9   2011  74126   8711367.0
# 10  2010  71971   3422724.0
# 11  2009  78792   5921786.0
# 12  2008  78979   5292468.0
# 13  2007  85705   9328045.0
# 14  2006  96385   9873745.0
# 15  2005  66753   8689389.0
# 17  2003  63629   3960842.0
# 18  2002  73457   7184712.0
# 19  2001  84079   3570911.0
# 20  2000  92250   7393493.0
# 21  1999  92487   5626093.0
# 22  1998  81043   1329704.0
# 23  1997  66196   2856959.0
# 24  1996  96363   6065998.0
# 25  1995  82234   1840546.0
# 26  1994  79107   4073579.0
# 27  1993  58810   1797574.0
# 28  1992  87394   2069929.0
# 29  1991  75754   2953578.0
# 30  1990  66481   4621621.0
# 31  1989  48949   1827310.0
# 32  1988  72750   5009290.0
# ...
